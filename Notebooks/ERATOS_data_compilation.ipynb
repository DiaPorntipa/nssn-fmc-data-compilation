# %% [markdown]
# <a href="https://colab.research.google.com/github/DiaPorntipa/Bushfire_data_analytics/blob/main/Acclimatised_data_compilation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Start
#
#
# This script prepares vapor pressure deficit (VPD) data from acclimatised and matches it with VPD from field observations for subsequent analysis.
#
# TODO (HIGH): The information below is the copy of documentation of another script. Update it.
#
# 📄 **What this script does**
# 1. Loads cleaned field data with topography — for example, output from `Nick_phd_data_complilation.ipynb`.
# 2. Downloads **acclimatised data** for the grid cells closest to the field sites, spanning from the first day to one day after the last day of the field observations.
# 3. Find the field observations with the highest and lowest temperature between 9am to 9am of each day and put them separately in `df` and `df_min_temp`. When there are multiple observations with the highest or lowest temperatures, the ones with the lowest RH are selected.
# 4. Matches acclimatised temperature and RH values to the field observations in `df` and `df_min_temp` based on the nearest acclimatised grid cell and `acclimatised_observation_date`.
# 5. For both `df` and `df_min_temp`, calculates **VPD** (vapor pressure deficit) from the matched acclimatised temperature and RH.
# 6. Saves the combined field and acclimatised data as `acclimatised_max_temp.csv` and `acclimatised_min_temp.csv` in the `output/csv` folder.
#
#
# ⚠️ **Important notes**
# * Before running the script, set all variables in the **first cell**, and delete the **second cell** if not using a Google Colab environment.
#   *(The script was developed for use in Google Colab and has not been tested outside of it.)*

# %%
working_dir = "/content/drive/My Drive/Work/2025.04 ANU Bushfire"
explore_acclimatised_data = True

# %%
# Connect to Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Loading in-situ data

# %%
# Load in-situ_topography.csv as the main df

import pandas as pd
import os

df = pd.read_csv(os.path.join(working_dir, "output/csv/in-situ_topography.csv"))
df['Datetime'] = pd.to_datetime(df['Datetime'])

first_date, day_after_last_date = min(df['Datetime']).strftime("%Y%m%d"), (max(df['Datetime']) + pd.Timedelta(days=1)).strftime("%Y%m%d")
print("First date: ", first_date, ", One day after the last date: ", day_after_last_date)

df.head()
# Out:
# First date:  20181221 , One day after the last date:  20201107
#    Unnamed: 0  SiteID         X         Y            Datetime  Temperature  \
# 0           0      79  150.2953 -35.48254 2019-01-20 04:00:00       17.941
# 1           1      79  150.2953 -35.48254 2019-01-20 05:00:00       17.753
# 2           2      79  150.2953 -35.48254 2019-01-20 06:00:00       17.878
# 3           3      79  150.2953 -35.48254 2019-01-20 07:00:00       18.066
# 4           4      79  150.2953 -35.48254 2019-01-20 08:00:00       18.379
#
#           RH       VPD    slope     aspect     relief
# 0  97.525473  0.050885  7.76997  187.29736  27.341133
# 1  97.881611  0.043049  7.76997  187.29736  27.341133
# 2  98.236778  0.036114  7.76997  187.29736  27.341133
# 3  97.406114  0.053760  7.76997  187.29736  27.341133
# 4  97.881611  0.044776  7.76997  187.29736  27.341133

# %% [markdown]
# # Exploring Acclimatised data

# %%
acclimatised_data_dir = os.path.join(working_dir, "Data/Acclimatised")

acclimatised_df = None
if explore_acclimatised_data:
    acclimatised_df = pd.read_csv(os.path.join(acclimatised_data_dir, "SiteID-67_RH.csv"))
    print(acclimatised_df.info())
acclimatised_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DateTime_GMT  289 non-null    object
#  1   RH            289 non-null    float64
#  2   Longitude     289 non-null    float64
#  3   Latitude      289 non-null    float64
#  4   ModelErrAvg   289 non-null    float64
#  5   ModelType     289 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 13.7+ KB
# None
#             DateTime_GMT    RH  Longitude  Latitude  ModelErrAvg  \
# 0             2018-12-21  91.5   150.2697 -35.54484          4.8
# 1    2018-12-21 00:30:00  88.9   150.2697 -35.54484          4.9
# 2    2018-12-21 01:00:00  92.5   150.2697 -35.54484          4.2
# 3    2018-12-21 01:30:00  92.3   150.2697 -35.54484          4.1
# 4    2018-12-21 02:00:00  93.0   150.2697 -35.54484          3.4
# ..                   ...   ...        ...       ...          ...
# 284  2018-12-26 22:00:00  71.8   150.2697 -35.54484          5.1
# 285  2018-12-26 22:30:00  70.0   150.2697 -35.54484          5.6
# 286  2018-12-26 23:00:00  59.9   150.2697 -35.54484          5.7
# 287  2018-12-26 23:30:00  62.5   150.2697 -35.54484          5.7
# 288           2018-12-27  62.0   150.2697 -35.54484          5.8
#
#                          ModelType
# 0    Regression Trees with kriging
# 1                 TPS +1 covariate
# 2                TPS +3 covariates
# 3                 GLM with splines
# 4                TPS +2 covariates
# ..                             ...
# 284     Random Forest with splines
# 285     Random Forest with splines
# 286     Random Forest with kriging
# 287               TPS +1 covariate
# 288               TPS +1 covariate
#
# [289 rows x 6 columns]

# %% [markdown]
# # Combining in-situ and remote data into a single dataframe

# %%
# Generate UTC_Datetime for in-situ observations

from pytz import timezone

aus_tz = timezone('Australia/Sydney')
df['Datetime'] = df['Datetime'].dt.tz_localize(aus_tz, ambiguous='NaT', nonexistent='NaT')
df = df[~df['Datetime'].isna()]
df['UTC_Datetime'] = df['Datetime'].dt.tz_convert('UTC')

df.head()
# Out:
# <ipython-input-35-36cf8854994e>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['UTC_Datetime'] = df['Datetime'].dt.tz_convert('UTC')
#    Unnamed: 0  SiteID         X         Y                  Datetime  \
# 0           0      79  150.2953 -35.48254 2019-01-20 04:00:00+11:00
# 1           1      79  150.2953 -35.48254 2019-01-20 05:00:00+11:00
# 2           2      79  150.2953 -35.48254 2019-01-20 06:00:00+11:00
# 3           3      79  150.2953 -35.48254 2019-01-20 07:00:00+11:00
# 4           4      79  150.2953 -35.48254 2019-01-20 08:00:00+11:00
#
#    Temperature         RH       VPD    slope     aspect     relief  \
# 0       17.941  97.525473  0.050885  7.76997  187.29736  27.341133
# 1       17.753  97.881611  0.043049  7.76997  187.29736  27.341133
# 2       17.878  98.236778  0.036114  7.76997  187.29736  27.341133
# 3       18.066  97.406114  0.053760  7.76997  187.29736  27.341133
# 4       18.379  97.881611  0.044776  7.76997  187.29736  27.341133
#
#                UTC_Datetime
# 0 2019-01-19 17:00:00+00:00
# 1 2019-01-19 18:00:00+00:00
# 2 2019-01-19 19:00:00+00:00
# 3 2019-01-19 20:00:00+00:00
# 4 2019-01-19 21:00:00+00:00

# %%
# Fill in df with Acclimatised data

# For each row, open Acclimatised data csv file one-by-one to get data
def get_acclimatised_value(row, column):
    print(row)
    SiteID = row['SiteID']
    file_path = os.path.join(acclimatised_data_dir, f"SiteID-{SiteID}_{column}.csv")
    df_acclimatised = pd.read_csv(file_path)

    target_time = row['UTC_Datetime'].round('30 min').strftime('%Y-%m-%d %H:%M:%S')
    if '00:00:00' in target_time:
        target_time = target_time.replace(' 00:00:00', '')
    column_name = df_acclimatised.columns[df_acclimatised.columns.str.contains(column)]
    # debug
    print(target_time, column_name)
    print(df_acclimatised)
    # if '2019-01-16' in target_time | ('2018-12-27' in target_time):
    #     import numpy as np
    #     return np.nan
    acclimatised_value = df_acclimatised.loc[df_acclimatised['DateTime_GMT'] == target_time, column_name].values[0][0]

    return acclimatised_value

df['acclimatised_Temperature'] = df.apply(lambda row: get_acclimatised_value(row, 'Temperature'), axis=1)
df['acclimatised_RH'] = df.apply(lambda row: get_acclimatised_value(row, 'RH'), axis=1)
df.head()
# Out:
# Unnamed: 0                              0
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 04:00:00+11:00
# Temperature                        17.941
# RH                              97.525473
# VPD                              0.050885
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-19 17:00:00+00:00
# Name: 0, dtype: object
# 2019-01-19 17:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                              1
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 05:00:00+11:00
# Temperature                        17.753
# RH                              97.881611
# VPD                              0.043049
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-19 18:00:00+00:00
# Name: 1, dtype: object
# 2019-01-19 18:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                              2
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 06:00:00+11:00
# Temperature                        17.878
# RH                              98.236778
# VPD                              0.036114
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-19 19:00:00+00:00
# Name: 2, dtype: object
# 2019-01-19 19:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                              3
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 07:00:00+11:00
# Temperature                        18.066
# RH                              97.406114
# VPD                               0.05376
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-19 20:00:00+00:00
# Name: 3, dtype: object
# 2019-01-19 20:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                              4
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 08:00:00+11:00
# Temperature                        18.379
# RH                              97.881611
# VPD                              0.044776
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-19 21:00:00+00:00
# Name: 4, dtype: object
# 2019-01-19 21:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                              5
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 09:00:00+11:00
# Temperature                        19.192
# RH                              93.557496
# VPD                              0.143272
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-19 22:00:00+00:00
# Name: 5, dtype: object
# 2019-01-19 22:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                              6
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 10:00:00+11:00
# Temperature                        20.006
# RH                              92.090247
# VPD                              0.185021
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-19 23:00:00+00:00
# Name: 6, dtype: object
# 2019-01-19 23:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                              7
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 11:00:00+11:00
# Temperature                        21.069
# RH                               88.24163
# VPD                              0.293673
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 00:00:00+00:00
# Name: 7, dtype: object
# 2019-01-20 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                              8
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 12:00:00+11:00
# Temperature                        21.882
# RH                              83.021834
# VPD                              0.445673
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 01:00:00+00:00
# Name: 8, dtype: object
# 2019-01-20 01:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                              9
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 13:00:00+11:00
# Temperature                         23.07
# RH                              82.633673
# VPD                              0.489966
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 02:00:00+00:00
# Name: 9, dtype: object
# 2019-01-20 02:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             10
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 14:00:00+11:00
# Temperature                         23.82
# RH                               80.29015
# VPD                              0.581801
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 03:00:00+00:00
# Name: 10, dtype: object
# 2019-01-20 03:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             11
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 15:00:00+11:00
# Temperature                        22.507
# RH                              84.564774
# VPD                              0.420879
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 04:00:00+00:00
# Name: 11, dtype: object
# 2019-01-20 04:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             12
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 16:00:00+11:00
# Temperature                         22.07
# RH                              84.692868
# VPD                               0.40644
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 05:00:00+00:00
# Name: 12, dtype: object
# 2019-01-20 05:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             13
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 17:00:00+11:00
# Temperature                        21.569
# RH                              84.692868
# VPD                              0.394199
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 06:00:00+00:00
# Name: 13, dtype: object
# 2019-01-20 06:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             14
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 18:00:00+11:00
# Temperature                        21.069
# RH                              87.235323
# VPD                              0.318806
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 07:00:00+00:00
# Name: 14, dtype: object
# 2019-01-20 07:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             15
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 19:00:00+11:00
# Temperature                        21.132
# RH                              86.729743
# VPD                              0.332717
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 08:00:00+00:00
# Name: 15, dtype: object
# 2019-01-20 08:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             16
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 20:00:00+11:00
# Temperature                        20.631
# RH                              87.487627
# VPD                                0.3042
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 09:00:00+00:00
# Name: 16, dtype: object
# 2019-01-20 09:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             17
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 21:00:00+11:00
# Temperature                        20.256
# RH                              90.982048
# VPD                               0.21423
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 10:00:00+00:00
# Name: 17, dtype: object
# 2019-01-20 10:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             18
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 22:00:00+11:00
# Temperature                        19.881
# RH                              92.213489
# VPD                              0.180734
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 11:00:00+00:00
# Name: 18, dtype: object
# 2019-01-20 11:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             19
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-20 23:00:00+11:00
# Temperature                        19.943
# RH                               95.13149
# VPD                              0.113438
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 12:00:00+00:00
# Name: 19, dtype: object
# 2019-01-20 12:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             20
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-21 00:00:00+11:00
# Temperature                        19.568
# RH                              94.406599
# VPD                              0.127333
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 13:00:00+00:00
# Name: 20, dtype: object
# 2019-01-20 13:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             21
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-21 01:00:00+11:00
# Temperature                        19.505
# RH                               94.89083
# VPD                              0.115855
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 14:00:00+00:00
# Name: 21, dtype: object
# 2019-01-20 14:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             22
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-21 02:00:00+11:00
# Temperature                        19.693
# RH                               95.61378
# VPD                              0.100629
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 15:00:00+00:00
# Name: 22, dtype: object
# 2019-01-20 15:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             23
# SiteID                                 79
# X                                150.2953
# Y                               -35.48254
# Datetime        2019-01-21 03:00:00+11:00
# Temperature                        19.755
# RH                               95.13149
# VPD                              0.112124
# slope                             7.76997
# aspect                          187.29736
# relief                          27.341133
# UTC_Datetime    2019-01-20 16:00:00+00:00
# Name: 23, dtype: object
# 2019-01-20 16:00:00 Index(['AirTemperature'], dtype='object')
#             DateTime_GMT  AirTemperature  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16            27.6   150.2953 -35.48254          0.8
# 1    2019-01-16 00:30:00            28.2   150.2953 -35.48254          0.9
# 2    2019-01-16 01:00:00            29.1   150.2953 -35.48254          1.1
# 3    2019-01-16 01:30:00            29.1   150.2953 -35.48254          1.1
# 4    2019-01-16 02:00:00            29.8   150.2953 -35.48254          1.2
# ..                   ...             ...        ...       ...          ...
# 668  2019-01-29 22:00:00            24.4   150.2953 -35.48254          0.7
# 669  2019-01-29 22:30:00            25.4   150.2953 -35.48254          0.7
# 670  2019-01-29 23:00:00            26.5   150.2953 -35.48254          0.9
# 671  2019-01-29 23:30:00            26.1   150.2953 -35.48254          0.9
# 672           2019-01-30            27.2   150.2953 -35.48254          1.0
#
#                          ModelType
# 0       Random Forest with kriging
# 1       Random Forest with kriging
# 2       Random Forest with kriging
# 3       Random Forest with kriging
# 4    Regression Trees with kriging
# ..                             ...
# 668               SVM with kriging
# 669               SVM with kriging
# 670               SVM with kriging
# 671     Random Forest with kriging
# 672               SVM with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                             24
# SiteID                                 79
# X                                150.2953
# ...
# Y                                           -35.48254
# Datetime                    2019-01-24 01:00:00+11:00
# Temperature                                    19.881
# RH                                          97.643862
# VPD                                          0.054689
# slope                                         7.76997
# aspect                                      187.29736
# relief                                      27.341133
# UTC_Datetime                2019-01-23 14:00:00+00:00
# acclimatised_Temperature                         20.5
# Name: 93, dtype: object
# 2019-01-23 14:00:00 Index(['RH'], dtype='object')
#             DateTime_GMT    RH  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16  61.4   150.2953 -35.48254          5.2
# 1    2019-01-16 00:30:00  61.3   150.2953 -35.48254          5.4
# 2    2019-01-16 01:00:00  55.5   150.2953 -35.48254          5.7
# 3    2019-01-16 01:30:00  64.2   150.2953 -35.48254          6.2
# 4    2019-01-16 02:00:00  61.7   150.2953 -35.48254          6.2
# ..                   ...   ...        ...       ...          ...
# 668  2019-01-29 22:00:00  84.4   150.2953 -35.48254          4.4
# 669  2019-01-29 22:30:00  76.4   150.2953 -35.48254          4.2
# 670  2019-01-29 23:00:00  76.0   150.2953 -35.48254          5.1
# 671  2019-01-29 23:30:00  72.4   150.2953 -35.48254          5.5
# 672           2019-01-30  71.7   150.2953 -35.48254          5.7
#
#                          ModelType
# 0       Random Forest with splines
# 1       Random Forest with splines
# 2       Random Forest with splines
# 3                TPS +2 covariates
# 4                TPS +2 covariates
# ..                             ...
# 668              TPS +3 covariates
# 669               TPS +1 covariate
# 670               SVM with kriging
# 671  Regression Trees with splines
# 672     Random Forest with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                                         94
# SiteID                                             79
# X                                            150.2953
# Y                                           -35.48254
# Datetime                    2019-01-24 02:00:00+11:00
# Temperature                                     19.63
# RH                                          97.287724
# VPD                                          0.061983
# slope                                         7.76997
# aspect                                      187.29736
# relief                                      27.341133
# UTC_Datetime                2019-01-23 15:00:00+00:00
# acclimatised_Temperature                         20.7
# Name: 94, dtype: object
# 2019-01-23 15:00:00 Index(['RH'], dtype='object')
#             DateTime_GMT    RH  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16  61.4   150.2953 -35.48254          5.2
# 1    2019-01-16 00:30:00  61.3   150.2953 -35.48254          5.4
# 2    2019-01-16 01:00:00  55.5   150.2953 -35.48254          5.7
# 3    2019-01-16 01:30:00  64.2   150.2953 -35.48254          6.2
# 4    2019-01-16 02:00:00  61.7   150.2953 -35.48254          6.2
# ..                   ...   ...        ...       ...          ...
# 668  2019-01-29 22:00:00  84.4   150.2953 -35.48254          4.4
# 669  2019-01-29 22:30:00  76.4   150.2953 -35.48254          4.2
# 670  2019-01-29 23:00:00  76.0   150.2953 -35.48254          5.1
# 671  2019-01-29 23:30:00  72.4   150.2953 -35.48254          5.5
# 672           2019-01-30  71.7   150.2953 -35.48254          5.7
#
#                          ModelType
# 0       Random Forest with splines
# 1       Random Forest with splines
# 2       Random Forest with splines
# 3                TPS +2 covariates
# 4                TPS +2 covariates
# ..                             ...
# 668              TPS +3 covariates
# 669               TPS +1 covariate
# 670               SVM with kriging
# 671  Regression Trees with splines
# 672     Random Forest with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                                         95
# SiteID                                             79
# X                                            150.2953
# Y                                           -35.48254
# Datetime                    2019-01-24 03:00:00+11:00
# Temperature                                    19.443
# RH                                          97.643862
# VPD                                          0.053222
# slope                                         7.76997
# aspect                                      187.29736
# relief                                      27.341133
# UTC_Datetime                2019-01-23 16:00:00+00:00
# acclimatised_Temperature                         20.6
# Name: 95, dtype: object
# 2019-01-23 16:00:00 Index(['RH'], dtype='object')
#             DateTime_GMT    RH  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16  61.4   150.2953 -35.48254          5.2
# 1    2019-01-16 00:30:00  61.3   150.2953 -35.48254          5.4
# 2    2019-01-16 01:00:00  55.5   150.2953 -35.48254          5.7
# 3    2019-01-16 01:30:00  64.2   150.2953 -35.48254          6.2
# 4    2019-01-16 02:00:00  61.7   150.2953 -35.48254          6.2
# ..                   ...   ...        ...       ...          ...
# 668  2019-01-29 22:00:00  84.4   150.2953 -35.48254          4.4
# 669  2019-01-29 22:30:00  76.4   150.2953 -35.48254          4.2
# 670  2019-01-29 23:00:00  76.0   150.2953 -35.48254          5.1
# 671  2019-01-29 23:30:00  72.4   150.2953 -35.48254          5.5
# 672           2019-01-30  71.7   150.2953 -35.48254          5.7
#
#                          ModelType
# 0       Random Forest with splines
# 1       Random Forest with splines
# 2       Random Forest with splines
# 3                TPS +2 covariates
# 4                TPS +2 covariates
# ..                             ...
# 668              TPS +3 covariates
# 669               TPS +1 covariate
# 670               SVM with kriging
# 671  Regression Trees with splines
# 672     Random Forest with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                                         96
# SiteID                                             79
# X                                            150.2953
# Y                                           -35.48254
# Datetime                    2019-01-24 04:00:00+11:00
# Temperature                                    19.318
# RH                                          98.118389
# VPD                                          0.042174
# slope                                         7.76997
# aspect                                      187.29736
# relief                                      27.341133
# UTC_Datetime                2019-01-23 17:00:00+00:00
# acclimatised_Temperature                         20.4
# Name: 96, dtype: object
# 2019-01-23 17:00:00 Index(['RH'], dtype='object')
#             DateTime_GMT    RH  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16  61.4   150.2953 -35.48254          5.2
# 1    2019-01-16 00:30:00  61.3   150.2953 -35.48254          5.4
# 2    2019-01-16 01:00:00  55.5   150.2953 -35.48254          5.7
# 3    2019-01-16 01:30:00  64.2   150.2953 -35.48254          6.2
# 4    2019-01-16 02:00:00  61.7   150.2953 -35.48254          6.2
# ..                   ...   ...        ...       ...          ...
# 668  2019-01-29 22:00:00  84.4   150.2953 -35.48254          4.4
# 669  2019-01-29 22:30:00  76.4   150.2953 -35.48254          4.2
# 670  2019-01-29 23:00:00  76.0   150.2953 -35.48254          5.1
# 671  2019-01-29 23:30:00  72.4   150.2953 -35.48254          5.5
# 672           2019-01-30  71.7   150.2953 -35.48254          5.7
#
#                          ModelType
# 0       Random Forest with splines
# 1       Random Forest with splines
# 2       Random Forest with splines
# 3                TPS +2 covariates
# 4                TPS +2 covariates
# ..                             ...
# 668              TPS +3 covariates
# 669               TPS +1 covariate
# 670               SVM with kriging
# 671  Regression Trees with splines
# 672     Random Forest with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                                         97
# SiteID                                             79
# X                                            150.2953
# Y                                           -35.48254
# Datetime                    2019-01-24 05:00:00+11:00
# Temperature                                     19.13
# RH                                          97.287724
# VPD                                          0.060084
# slope                                         7.76997
# aspect                                      187.29736
# relief                                      27.341133
# UTC_Datetime                2019-01-23 18:00:00+00:00
# acclimatised_Temperature                         20.0
# Name: 97, dtype: object
# 2019-01-23 18:00:00 Index(['RH'], dtype='object')
#             DateTime_GMT    RH  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16  61.4   150.2953 -35.48254          5.2
# 1    2019-01-16 00:30:00  61.3   150.2953 -35.48254          5.4
# 2    2019-01-16 01:00:00  55.5   150.2953 -35.48254          5.7
# 3    2019-01-16 01:30:00  64.2   150.2953 -35.48254          6.2
# 4    2019-01-16 02:00:00  61.7   150.2953 -35.48254          6.2
# ..                   ...   ...        ...       ...          ...
# 668  2019-01-29 22:00:00  84.4   150.2953 -35.48254          4.4
# 669  2019-01-29 22:30:00  76.4   150.2953 -35.48254          4.2
# 670  2019-01-29 23:00:00  76.0   150.2953 -35.48254          5.1
# 671  2019-01-29 23:30:00  72.4   150.2953 -35.48254          5.5
# 672           2019-01-30  71.7   150.2953 -35.48254          5.7
#
#                          ModelType
# 0       Random Forest with splines
# 1       Random Forest with splines
# 2       Random Forest with splines
# 3                TPS +2 covariates
# 4                TPS +2 covariates
# ..                             ...
# 668              TPS +3 covariates
# 669               TPS +1 covariate
# 670               SVM with kriging
# 671  Regression Trees with splines
# 672     Random Forest with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                                         98
# SiteID                                             79
# X                                            150.2953
# Y                                           -35.48254
# Datetime                    2019-01-24 06:00:00+11:00
# Temperature                                    19.192
# RH                                          97.881611
# VPD                                           0.04711
# slope                                         7.76997
# aspect                                      187.29736
# relief                                      27.341133
# UTC_Datetime                2019-01-23 19:00:00+00:00
# acclimatised_Temperature                         19.7
# Name: 98, dtype: object
# 2019-01-23 19:00:00 Index(['RH'], dtype='object')
#             DateTime_GMT    RH  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16  61.4   150.2953 -35.48254          5.2
# 1    2019-01-16 00:30:00  61.3   150.2953 -35.48254          5.4
# 2    2019-01-16 01:00:00  55.5   150.2953 -35.48254          5.7
# 3    2019-01-16 01:30:00  64.2   150.2953 -35.48254          6.2
# 4    2019-01-16 02:00:00  61.7   150.2953 -35.48254          6.2
# ..                   ...   ...        ...       ...          ...
# 668  2019-01-29 22:00:00  84.4   150.2953 -35.48254          4.4
# 669  2019-01-29 22:30:00  76.4   150.2953 -35.48254          4.2
# 670  2019-01-29 23:00:00  76.0   150.2953 -35.48254          5.1
# 671  2019-01-29 23:30:00  72.4   150.2953 -35.48254          5.5
# 672           2019-01-30  71.7   150.2953 -35.48254          5.7
#
#                          ModelType
# 0       Random Forest with splines
# 1       Random Forest with splines
# 2       Random Forest with splines
# 3                TPS +2 covariates
# 4                TPS +2 covariates
# ..                             ...
# 668              TPS +3 covariates
# 669               TPS +1 covariate
# 670               SVM with kriging
# 671  Regression Trees with splines
# 672     Random Forest with kriging
#
# [673 rows x 6 columns]
# Unnamed: 0                                         99
# SiteID                                             79
# X                                            150.2953
# Y                                           -35.48254
# Datetime                    2019-01-24 07:00:00+11:00
# Temperature                                    19.255
# RH                                          96.691897
# VPD                                          0.073857
# slope                                         7.76997
# aspect                                      187.29736
# relief                                      27.341133
# UTC_Datetime                2019-01-23 20:00:00+00:00
# acclimatised_Temperature                         20.2
# Name: 99, dtype: object
# 2019-01-23 20:00:00 Index(['RH'], dtype='object')
#             DateTime_GMT    RH  Longitude  Latitude  ModelErrAvg  \
# 0             2019-01-16  61.4   150.2953 -35.48254          5.2
# 1    2019-01-16 00:30:00  61.3   150.2953 -35.48254          5.4
# 2    2019-01-16 01:00:00  55.5   150.2953 -35.48254          5.7
# 3    2019-01-16 01:30:00  64.2   150.2953 -35.48254          6.2
# 4    2019-01-16 02:00:00  61.7   150.2953 -35.48254          6.2
# ..                   ...   ...        ...       ...          ...
# 668  2019-01-29 22:00:00  84.4   150.2953 -35.48254          4.4
# 669  2019-01-29 22:30:00  76.4   150.2953 -35.48254          4.2
# 670  2019-01-29 23:00:00  76.0   150.2953 -35.48254          5.1
# 671  2019-01-29 23:30:00  72.4   150.2953 -35.48254          5.5
# 672           2019-01-30  71.7   150.2953 -35.48254          5.7
#
#                          ModelType
# 0       Random Forest with splines
# 1       Random Forest with splines
# 2       Random Forest with splines
# 3                TPS +2 covariates
# 4                TPS +2 covariates
# ..                             ...
# 668              TPS +3 covariates
# 669               TPS +1 covariate
# 670               SVM with kriging
# 671  Regression Trees with splines
# 672     Random Forest with kriging
#
# [673 rows x 6 columns]
# <ipython-input-43-318d3b20cb7c>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['acclimatised_RH'] = df.apply(lambda row: get_acclimatised_value(row, 'RH'), axis=1)
#    Unnamed: 0  SiteID         X         Y                  Datetime  \
# 0           0      79  150.2953 -35.48254 2019-01-20 04:00:00+11:00
# 1           1      79  150.2953 -35.48254 2019-01-20 05:00:00+11:00
# 2           2      79  150.2953 -35.48254 2019-01-20 06:00:00+11:00
# 3           3      79  150.2953 -35.48254 2019-01-20 07:00:00+11:00
# 4           4      79  150.2953 -35.48254 2019-01-20 08:00:00+11:00
#
#    Temperature         RH       VPD    slope     aspect     relief  \
# 0       17.941  97.525473  0.050885  7.76997  187.29736  27.341133
# 1       17.753  97.881611  0.043049  7.76997  187.29736  27.341133
# 2       17.878  98.236778  0.036114  7.76997  187.29736  27.341133
# 3       18.066  97.406114  0.053760  7.76997  187.29736  27.341133
# 4       18.379  97.881611  0.044776  7.76997  187.29736  27.341133
#
#                UTC_Datetime  acclimatised_Temperature  acclimatised_RH
# 0 2019-01-19 17:00:00+00:00                      18.5             87.2
# 1 2019-01-19 18:00:00+00:00                      18.5             87.6
# 2 2019-01-19 19:00:00+00:00                      18.6             87.6
# 3 2019-01-19 20:00:00+00:00                      19.0             85.0
# 4 2019-01-19 21:00:00+00:00                      19.5             81.2

# %%
# Investigate the result
print("df length: ", len(df))
df[(df.isna().any(axis=1)) & (df['SiteID'] != 251)]
# Out:
# df length:  100
# Empty DataFrame
# Columns: [Unnamed: 0, SiteID, X, Y, Datetime, Temperature, RH, VPD, slope, aspect, relief, UTC_Datetime, acclimatised_Temperature, acclimatised_RH]
# Index: []

# %% [markdown]
# # Calculating remote VPD from remote temperature and remote relative humidity

# %%
# Write a function for deriving VPD from temp and RH

import math
import numpy as np

def calculate_vpd(temp, rh):
    if pd.isna(temp) or pd.isna(rh):
        return np.nan
    es = 0.6108 * math.exp(17.27 * temp / (237.3 + temp))
    e = es * rh / 100
    vpd = es - e
    return vpd

df['acclimatised_VPD'] = df.apply(lambda row: calculate_vpd(row['acclimatised_Temperature'], row['acclimatised_RH']), axis=1)
df.head()
# Out:
# <ipython-input-45-57c836cceacb>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['acclimatised_VPD'] = df.apply(lambda row: calculate_vpd(row['acclimatised_Temperature'], row['acclimatised_RH']), axis=1)
#    Unnamed: 0  SiteID         X         Y                  Datetime  \
# 0           0      79  150.2953 -35.48254 2019-01-20 04:00:00+11:00
# 1           1      79  150.2953 -35.48254 2019-01-20 05:00:00+11:00
# 2           2      79  150.2953 -35.48254 2019-01-20 06:00:00+11:00
# 3           3      79  150.2953 -35.48254 2019-01-20 07:00:00+11:00
# 4           4      79  150.2953 -35.48254 2019-01-20 08:00:00+11:00
#
#    Temperature         RH       VPD    slope     aspect     relief  \
# 0       17.941  97.525473  0.050885  7.76997  187.29736  27.341133
# 1       17.753  97.881611  0.043049  7.76997  187.29736  27.341133
# 2       17.878  98.236778  0.036114  7.76997  187.29736  27.341133
# 3       18.066  97.406114  0.053760  7.76997  187.29736  27.341133
# 4       18.379  97.881611  0.044776  7.76997  187.29736  27.341133
#
#                UTC_Datetime  acclimatised_Temperature  acclimatised_RH  \
# 0 2019-01-19 17:00:00+00:00                      18.5             87.2
# 1 2019-01-19 18:00:00+00:00                      18.5             87.6
# 2 2019-01-19 19:00:00+00:00                      18.6             87.6
# 3 2019-01-19 20:00:00+00:00                      19.0             85.0
# 4 2019-01-19 21:00:00+00:00                      19.5             81.2
#
#    acclimatised_VPD
# 0          0.272611
# 1          0.264092
# 2          0.265751
# 3          0.329609
# 4          0.426173

# %% [markdown]
# # Save the resulting dataframes

# %%
df.to_csv(os.path.join(working_dir, "output/csv/acclimatised.csv"), index=False)
